# %%
# we need to plot the raw ECG data, so we will use matplotlib libraryto do that
# we want to make sure to label the axes to the plot
import matplotlib.pyplot as plt

# %%
# check visually if the plot is correctly labeled

# %%
#plot using matplotlib
plt.plot(ECGu.txt)
plt.xlabel("Time (s)")
plt.ylabel("Voltage (mV)")
plt.title("Raw ECG Data")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 #plot using matplotlib
# ----> 2 plt.plot(ECGu.txt)
#       3 plt.xlabel("Time (s)")
#       4 plt.ylabel("Voltage (mV)")
#       5 plt.title("Raw ECG Data")
#
# NameError: name 'ECGu' is not defined
